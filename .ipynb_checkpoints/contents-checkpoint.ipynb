# %% [markdown]
# ＜はじめましてJulia(仮)＞
#
# 0. 実行 =>生松
# ・対話的実行
# ・コンパイル実行(hello world, セッション終了:ctrl D)
#
# 1. 基本 =>生松 \
# ・変数 \
# ・print, println（$で文字列に変数を埋め込む、@printfで変数を埋め込む） \
# ・型（bool, float32, 64, int, 文字列, typeof, BigInt,BigFLoat） \
# ・演算（四則演算、余り、冪乗、整数・小数同士の計算、比較演算子、isnan/isinfなどのチェック） \
# ・文字列（結合、大文字小文字、数値型変換） \
# ・文字列のスライス（※インデックスは1始まり） \
# ・正規表現 \
# \
# \
#
# 参考：https://docs.julialang.org/en/v1/manual/mathematical-operations/ \
# \
# 2. データ構造 =>生松 \
# ・タプル（名前付き, immutable） \
# ・リスト（1次元array型） \
# ・辞書型 \
# ・構造体：struct \
# ・（集合(in, )） \
# \
# 3. 配列 ＝＞ 小谷 \
# ・配列の定義(Array, zeros, ones, rand, randn, fill, fill!, reshape, copy, deepcopy) \
# ・配列の演算\
# ・関数（map, filter, append!, push!, pop!, insert!, shift!, end, length, size, eltype, ndims）\
# \
# 参考：https://qiita.com/A03ki/items/007be353411d19952ef7 \
#  \
# 4. 制御構造 =>生松 \
# ・if文 \
# ・whileループ \
# ・forループ(range, zip) \
# ・内包表記 \
# \
# 5. 関数 =>生松 \
# ・関数　 \
# ・無名関数 \
# （・多重ディスパッチ） \
# \
# 6. モジュール, パッケージ （5と一緒にする？） => 生松 \
# ・モジュール(module) \
# （・名前空間） \
# ・パッケージ \
#
# \
# 7. 科学計算 ＝＞ 小谷 \
# ・ベクトル、行列演算（定義、単位行列、ゼロ行列、ベクトルと行列の変換） \
# ・三角関数 \
# ・指数、対数関数 \
# ・いろいろ（複素数、abs, sign, 円周率, exp...) \
#  \
# 8. ファイル入出力 ＝＞ 生松 \
# ・csv読み込み\
# ・csv書き込み\
# （・json） \
# \
# 9. 可視化（PyPlot.jl） =>生松 \
# ・線プロット、点プロット \
# ・ヒストグラム \
# ・散布図 \
# ・複数プロット \
# ・プロットファイル保存 \
#
# =====次の段階\
#  \
# （・メタプログラミング、マクロ）\
# （・データフレーム）\
# （・回帰分析、クラス分け、クラスタリング）\
# （・実行速度の比較）\
# \
# =====あわよくば\
# \
# （・他言語C, Fortran, Python, Linuxの呼び出し）\
# （・科学計算ライブラリ：数値積分：QuadGK.jl、常微分方程式：DifferentialEquations.jl）\
# \
# 発展：Juliaプログラミングクックブック \
